# %%
kg = int(input('kg '))
lbs = kg * 2.204
lbs
# Out:
# kg  1
# 2.204

# %%
pi = 3.14
r = int(input('Your r '))
c = 2*pi*r
print(round(c,1))
# Out:
# Your r  29
# 182.1

# %%
x = 34
x = x*3
x = x+6
x = x/3
x = x - 34
x
# Out:
# 2.0
